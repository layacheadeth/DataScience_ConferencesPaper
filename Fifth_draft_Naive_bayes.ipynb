# %%
import pandas as pd
import fractions
import re
import string
import nltk
import spacy 
import numpy as np
import math
from tqdm import tqdm 

from spacy.matcher import Matcher
from spacy.tokens import Span
from spacy import displacy



data=pd.read_csv("df_product_test.csv")
data
# Out:
#                                                Product  name  \
# 0                              Baby Trend Diaper Champ   333
# 1                          BABYBJORN Potty Chair - Red   232
# 2                     Philips Avent 3 Pack 9oz Bottles   191
# 3                           Munchkin Mozart Magic Cube   191
# 4                          PRIMO EuroBath, Pearl White   182
# ..                                                 ...   ...
# 356  Semanario (7) Little Girls 14k Gold Overlay Ba...     1
# 357        Gerber Diaper Service Cloth Diapers (6-pk.)     1
# 358  Large Jungle Animals (Panda, Lion, Elephant, G...     1
# 359  Beautiful Girl and Black Flower Removable Viny...     1
# 360              Playtex VentAire Bottle 6 oz. - 1 pk.     1
#
#                    Category
# 0                 Diapering
# 1                   Nursery
# 2                 Baby_care
# 3    Activity_entertainment
# 4                   Nursery
# ..                      ...
# 356     Apparel_accessories
# 357               Diapering
# 358       Baby_toddler_toys
# 359                 Nursery
# 360               Baby_care
#
# [361 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
data.head()
# Out:
#                             Product  name                Category
# 0           Baby Trend Diaper Champ   333               Diapering
# 1       BABYBJORN Potty Chair - Red   232                 Nursery
# 2  Philips Avent 3 Pack 9oz Bottles   191               Baby_care
# 3        Munchkin Mozart Magic Cube   191  Activity_entertainment
# 4       PRIMO EuroBath, Pearl White   182                 Nursery

# %%
data_new = data.rename(columns={'total': 'name'}, index={'ONE': 'Row_1'})

# %%
data_new.head()
# Out:
#                             Product  name                Category
# 0           Baby Trend Diaper Champ   333               Diapering
# 1       BABYBJORN Potty Chair - Red   232                 Nursery
# 2  Philips Avent 3 Pack 9oz Bottles   191               Baby_care
# 3        Munchkin Mozart Magic Cube   191  Activity_entertainment
# 4       PRIMO EuroBath, Pearl White   182                 Nursery

# %%
count_vec=CountVectorizer()
bow=count_vec.fit_transform(data_new['Product'])
bow=np.array(bow.todense())

# %%
x=bow
y=data_new['Category']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,stratify=y)

# %%
model=MultinomialNB().fit(X_train,y_train)

# %%
y_pred=model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5045871559633027

# %%
f1_score(y_test,y_pred,average='macro')
# Out:
# 0.32502129056750906

# %%
print(classification_report(y_test, y_pred))
# Out:
#                         precision    recall  f1-score   support
#
# Activity_entertainment       0.00      0.00      0.00         2
#    Apparel_accessories       0.00      0.00      0.00         2
#              Baby_care       0.22      0.25      0.24        16
#        Baby_stationary       0.00      0.00      0.00         3
#      Baby_toddler_toys       0.69      0.60      0.64        15
#   CarSeats_accessories       0.50      0.25      0.33         4
#              Diapering       0.75      0.50      0.60         6
#                Feeding       0.52      0.89      0.65        19
#                  Gifts       0.00      0.00      0.00         2
#                Nursery       0.59      0.53      0.56        19
#         Potty_training       0.00      0.00      0.00         2
#    Pregnancy_maternity       0.00      0.00      0.00         3
#                 Safety       0.45      0.64      0.53        14
#  Strollers_accessories       1.00      1.00      1.00         2
#
#               accuracy                           0.50       109
#              macro avg       0.34      0.33      0.33       109
#           weighted avg       0.46      0.50      0.47       109
# /Users/deth/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/deth/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/deth/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
results = pd.DataFrame(data={'predicted': y_pred, 'actual': y_test})
results['result'] = np.where(results['predicted']==results['actual'], 1, 0)
results.sort_values(by='result').head(20)
# Out:
#              predicted                  actual  result
# 283             Safety                 Nursery       0
# 275            Feeding               Diapering       0
# 272             Safety                 Nursery       0
# 91             Feeding     Pregnancy_maternity       0
# 90             Feeding                 Nursery       0
# 355            Feeding               Baby_care       0
# 104            Feeding       Baby_toddler_toys       0
# 45           Baby_care  Activity_entertainment       0
# 79             Feeding     Pregnancy_maternity       0
# 307          Baby_care                   Gifts       0
# 68           Baby_care                  Safety       0
# 114            Nursery               Baby_care       0
# 255             Safety               Baby_care       0
# 113            Nursery               Diapering       0
# 266          Baby_care                  Safety       0
# 95           Baby_care                 Feeding       0
# 29             Feeding          Potty_training       0
# 176  Baby_toddler_toys                  Safety       0
# 36             Feeding       Baby_toddler_toys       0
# 238          Baby_care         Baby_stationary       0
