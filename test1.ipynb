# %%
import pandas as pd
doc=pd.read_csv("used6.csv")
doc
# Out:
#      Unnamed: 0                                               name  \
# 0             0                           Planetwise Flannel Wipes
# 1             1                              Planetwise Wipe Pouch
# 2             2                Annas Dream Full Quilt with 2 Shams
# 3             3  Stop Pacifier Sucking without tears with Thumb...
# 4             4  Stop Pacifier Sucking without tears with Thumb...
# ..          ...                                                ...
# 416         418    Amazon.com Gift Card in a Welcome Baby Gift Box
# 417         419    Amazon.com Gift Card in a Welcome Baby Gift Box
# 418         420    Amazon.com Gift Card in a Welcome Baby Gift Box
# 419         421    Amazon.com Gift Card in a Welcome Baby Gift Box
# 420         422    Amazon.com Gift Card in a Welcome Baby Gift Box
#
#                                                 review  index   Category
# 0    These flannel wipes are OK, but in my opinion ...      0  Baby_Care
# ...

# %%
doc1=doc.groupby('Category').count()
doc1.sort_values(by=['name'],ascending=False)
# Out:
#                         Unnamed: 0  name  review  index
# Category
# Baby_Care                       82    82      82     82
# Baby_toddler_toys               82    82      82     82
# Baby_stationary                 71    71      71     71
# Nursery                         55    55      55     55
# Gift                            46    46      46     46
# Activity_entertainment          37    37      37     37
# Diapering                       30    30      30     30
# Apparel_accessories             18    18      18     18
